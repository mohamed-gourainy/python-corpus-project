# %%
import pandas as pd
from IPython.display import display
import ipywidgets as widgets

from Corpus import Corpus
from DocumentFactory import DocumentFactory
from SearchEngine import SearchEngine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from IPython.display import display
#       3 import ipywidgets as widgets
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dell\Poker_App_str\venv\Scripts\python.exe

# %%
corpus = Corpus.get_instance("Corpus TD8 Notebook")

# éviter de recharger si déjà rempli
if not corpus.id2doc:
    factory = DocumentFactory()
    corpus.load("corpus_td6.tsv", factory)

print(corpus)
print("Docs:", corpus.ndoc, "| Auteurs:", corpus.naut)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 corpus = Corpus.get_instance("Corpus TD8 Notebook")
#       3 # éviter de recharger si déjà rempli
#       4 if not corpus.id2doc:
#
# NameError: name 'Corpus' is not defined
